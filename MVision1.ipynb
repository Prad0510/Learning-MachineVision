# %% [markdown]
# <a href="https://colab.research.google.com/github/Prad0510/Learning-MachineVision/blob/main/MVision1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c31ba26e-e7a9-4567-9076-6bc41f64c84c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c31ba26e-e7a9-4567-9076-6bc41f64c84c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img = cv2.imread(list(uploaded.keys())[0])

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("Original Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1279.5), np.float64(799.5), np.float64(-0.5))

# %%
print("Image Type:", type(img))
print("Data Type (Pixel values):", img.dtype)
print("Image Shape (H, W, C):", img.shape)
# Out:
# Image Type: <class 'numpy.ndarray'>
# Data Type (Pixel values): uint8
# Image Shape (H, W, C): (800, 1280, 3)

# %%
total_pixels = height * width
print("Total Number of Pixels:", total_pixels)
# Out:
# Total Number of Pixels: 1024000

# %%
print("Image Size in Bytes:", img.nbytes)
# Out:
# Image Size in Bytes: 3072000

# %%
pil_img = Image.open(image_path)
print("Image Format:", pil_img.format)
print("Image Mode:", pil_img.mode)   # RGB / L / etc.
print("Image Size (WxH):", pil_img.size)
# Out:
# Image Format: JPEG
# Image Mode: RGB
# Image Size (WxH): (5460, 3071)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

print("\n--- Grayscale Image Details ---")
print("Shape:", gray.shape)
print("Channels: 1")
print("Total Pixels:", gray.size)
print("Min Pixel Value:", gray.min())
print("Max Pixel Value:", gray.max())
# Out:
# --- Grayscale Image Details ---
# Shape: (800, 1280)
# Channels: 1
# Total Pixels: 1024000
# Min Pixel Value: 0
# Max Pixel Value: 250

# %%
plt.imshow(gray, cmap='gray')
plt.title("Grayscale Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1279.5), np.float64(799.5), np.float64(-0.5))

# %%
print(gray[0:5, 0:5])
# Out:
# [[51 50 46 53 51]
#  [49 52 52 53 52]
#  [46 52 57 52 55]
#  [45 50 57 52 58]
#  [50 49 55 53 59]]

# %%
plt.figure(figsize=(8,5))
plt.hist(gray.ravel(), bins=256, range=[0,256])
plt.title("Histogram of Grayscale Image")
plt.xlabel("Gray Level (0–255)")
plt.ylabel("Number of Pixels")
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-163f8a53-2d2a-469e-845a-5a3f63553396" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-163f8a53-2d2a-469e-845a-5a3f63553396">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img1 = cv2.imread(list(uploaded.keys())[0])

# %%
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
plt.title("Original Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(240.5), np.float64(-0.5))

# %%
print("Image Type:", type(img1))
print("Data Type (Pixel values):", img1.dtype)
print("Image Shape (H, W, C):", img1.shape)
# Out:
# Image Type: <class 'numpy.ndarray'>
# Data Type (Pixel values): uint8
# Image Shape (H, W, C): (241, 300, 3)

# %%
gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

# %%
print("Shape:", gray.shape)
print("Channels: 1")
print("Total Pixels:", gray.size)
print("Min Pixel Value:", gray.min())
print("Max Pixel Value:", gray.max())
# Out:
# Shape: (800, 1280)
# Channels: 1
# Total Pixels: 1024000
# Min Pixel Value: 0
# Max Pixel Value: 250

# %%
plt.imshow(gray1, cmap='gray')
plt.title("Grayscale Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(240.5), np.float64(-0.5))

# %%
plt.figure(figsize=(8,5))
plt.hist(gray1.ravel(), bins=256, range=[0,256])
plt.title("Histogram of Grayscale Image")
plt.xlabel("Gray Level (0–255)")
plt.ylabel("Number of Pixels")
plt.show()
